# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Find Diagonal Order

# %%
from leetcode.find_diagonal_order import find_diagonal_order
mat = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

y = find_diagonal_order(mat)
plt.plot(y)
plt.show()
